# %%
import pandas as pd

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic['age'] = titanic['age'].replace(['?'], [None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype('float')

# %%
titanic['lower_name'] = titanic['name'].str.lower()

# %%
titanic.lower_name.str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name
# 0                       allen, miss. elisabeth walton
# 1                      allison, master. hudson trevor
# 2                        allison, miss. helen loraine
# 3                allison, mr. hudson joshua creighton
# 4     allison, mrs. hudson j c (bessie waldo daniels)
# ...                                               ...
# 1304                             zabour, miss. hileni
# 1305                            zabour, miss. thamine
# 1306                        zakarian, mr. mapriededer
# 1307                              zakarian, mr. ortin
# 1308                               zimmerman, mr. leo
#
# [1309 rows x 15 columns]

# %%
"hello"[0]
# Out:
# 'h'

# %%
titanic["desk"] = titanic['cabin'].str[0]

# %%
titanic.groupby("desk")['survived'].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='desk'>

# %%
s = pd.Series(["1. Hawk.   ", "2. Pickle!\n", "3. Melonhead?\t"])

# %%
s
# Out:
# 0        1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip(to_strip="123. \n \t")
# Out:
# 0          Hawk
# 1       Pickle!
# 2    Melonhead?
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.lstrip("123.")
# Out:
# 0         Hawk.
# 1        Pickle!\n
# 2     Melonhead?\t
# dtype: object

# %%
titanic["home.dest"].str.split("/", expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home"] = titanic["home.dest"].str.split("/", expand=True)[0]

# %%
titanic.cabin.replace("?", "???")
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["destination"] = titanic["home.dest"].str.split("/", expand=True)[1]

# %%
titanic["home"].value_counts()
# Out:
# ?                                564
# New York, NY                      64
# Cornwall                          19
# London                            14
# London                            13
#                                 ...
# Chelsea, London                    1
# Harrow-on-the-Hill, Middlesex      1
# Copenhagen, Denmark                1
# Frankfort, KY                      1
# Antwerp, Belgium                   1
# Name: home, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Rochester, NY       1
#   New York, NY       1
#  Pennsylvania        1
#  Toledo, OH          1
#  Stanton, OH         1
# Name: destination, Length: 77, dtype: int64

# %%
titanic["home.dest"].str.split("/", expand=True,n=1)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest  \
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
#                                            lower_name desk           home  \
# 0                       allen, miss. elisabeth walton    B   St Louis, MO
# 1                      allison, master. hudson trevor    C  Montreal, PQ
# 2                        allison, miss. helen loraine    C  Montreal, PQ
# 3                allison, mr. hudson joshua creighton    C  Montreal, PQ
# 4     allison, mrs. hudson j c (bessie waldo daniels)    C  Montreal, PQ
# ...                                               ...  ...            ...
# 1304                             zabour, miss. hileni    ?              ?
# 1305                            zabour, miss. thamine    ?              ?
# 1306                        zakarian, mr. mapriededer    ?              ?
# 1307                              zakarian, mr. ortin    ?              ?
# 1308                               zimmerman, mr. leo    ?              ?
#
#             destination
# 0                  None
# 1      Chesterville, ON
# 2      Chesterville, ON
# 3      Chesterville, ON
# 4      Chesterville, ON
# ...                 ...
# 1304               None
# 1305               None
# 1306               None
# 1307               None
# 1308               None
#
# [1309 rows x 18 columns]

# %%
ufos = pd.read_csv("data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# 0        VA  2019-12-12T18:43:00      light    5 seconds
# 1        CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2       NaN                  NaN        NaN          NaN
# 3        ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4        NY  2009-03-15T18:00:00      cigar    2 minutes
# ...     ...                  ...        ...          ...
# 88120    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121    MO  2019-10-02T20:00:00      light   20 seconds
# 88122    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %%
ufos["duration"].str.replace("seconds|minutes", "", regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
    return reo.group()[0]

# %%
ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# Out:
# C:\Users\vikto\AppData\Local\Temp\ipykernel_5716\3522404207.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.contains("5")
# Out:
# 0         True
# 1         True
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"]
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos["duration"].str.contains("day|week", na=False)]
# Out:
#                                                  summary           city state  \
# 116    Saw one large ship during the day around noon ...      Knoxville    TN
# 1636   Right before day break, looked like old "ticke...     Seagoville    TX
# 3388   Abduction of myself and my child, age 5. We we...       Richmond    VA
# 3996   Everyone in my family remembers the nightly si...      La Mirada    CA
# 4921   San Francisco man, then 22, reported details o...  San Francisco    CA
# ...                                                  ...            ...   ...
# 84021  The Beings and Craft of Taos County.  ((NUFORC...           Taos    NM
# 84983  In 1967 I am a little kid now. I am sleeping I...         Saugas    CA
# 85717  There was a big bright colored triangle object...        Houston    BC
# 86210  2 flying diamonds; red and gold lights; creaki...         Dallas    TX
# 87707  Lights seen from the night sky 1st night-flick...          Haiku    HI
#
#                  date_time      shape        duration  \
# 116    1986-04-04T23:00:00  rectangle            week
# 1636   2004-05-01T05:00:00      other  till day break
# 3388   2018-08-30T03:00:00   changing          3 days
# 3996                   NaN      cigar    several days
# 4921                   NaN       disk          3 days
# ...                    ...        ...             ...
# 84021  2019-09-01T10:00:00      other          2 days
# 84983                  NaN        NaN          3 days
# 85717  2019-11-25T03:30:00   triangle   Till daylight
# 86210  2019-10-11T01:44:00    diamond          2 days
# 87707  2019-11-25T00:00:00      light          4 days
#
#                                                    stats  \
# 116    Occurred : 4/4/1986 23:00  (Entered as : 03150...
# 1636   Occurred : 5/1/2004 05:00  (Entered as : 2004-...
# 3388   Occurred : 8/30/2018 03:00  (Entered as : 08/3...
# 3996   Occurred : 6/30/1961 19:00  (Entered as : 1961...
# 4921   Occurred : 6/1/1963   (Entered as : 1963) Repo...
# ...                                                  ...
# 84021  Occurred : 9/1/2019 10:00  (Entered as : 09/01...
# 84983  Occurred : 6/30/1967 04:00 Reported: 12/19/201...
# 85717  Occurred : 11/25/2019 03:30  (Entered as : 11/...
# 86210  Occurred : 10/11/2019 01:44  (Entered as : 10/...
# 87707  Occurred : 11/25/2019  Reported: 11/29/2019 7:...
#
#                                              report_link  \
# 116     http://www.nuforc.org/webreports/049/S49786.html
# 1636   http://www.nuforc.org/webreports/147/S147593.html
# 3388   http://www.nuforc.org/webreports/145/S145403.html
# 3996    http://www.nuforc.org/webreports/052/S52256.html
# 4921    http://www.nuforc.org/webreports/057/S57316.html
# ...                                                  ...
# 84021  http://www.nuforc.org/webreports/148/S148913.html
# 84983  http://www.nuforc.org/webreports/144/S144137.html
# 85717  http://www.nuforc.org/webreports/151/S151095.html
# 86210  http://www.nuforc.org/webreports/150/S150378.html
# 87707  http://www.nuforc.org/webreports/151/S151166.html
#
#                                                     text               posted  \
# 116    Saw one large ship during the day around noon ...  2006-05-15T00:00:00
# 1636   Right before day break, looked like old &quot;...  2019-07-25T00:00:00
# 3388   Abduction of myself and my child, age 5.  We w...  2019-04-08T00:00:00
# 3996   Everyone in my family remembers the nightly si...                  NaN
# 4921   San Francisco man, then 22, reported details o...                  NaN
# ...                                                  ...                  ...
# 84021  The Beings and Craft of Taos County. ((NUFORC ...  2019-09-19T00:00:00
# 84983  In 1967 I am a little kid now.  I am sleeping ...                  NaN
# 85717  There was a big bright colored triangle object...  2019-12-01T00:00:00
# 86210  2 flying diamonds; red and gold lights; creaki...  2019-12-01T00:00:00
# 87707  Lights seen from the night sky 1st night-flick...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 116        35.961561      -83.980115
# 1636       32.595600      -96.558400
# 3388       37.558608      -77.507980
# 3996       33.901970     -118.007753
# 4921       37.769992     -122.425394
# ...              ...             ...
# 84021      36.414600     -105.522200
# 84983            NaN             NaN
# 85717      54.400000     -126.650000
# 86210      32.835168      -96.808118
# 87707      20.858800     -156.140500
#
# [173 rows x 12 columns]

# %%
def years_to_days(yrs):
    return yrs*365

# %%
years_to_days(3)
# Out:
# 1095

# %%
titanic["age"].apply(years_to_days)
# Out:
# 0       10585.0000
# 1         334.5955
# 2         730.0000
# 3       10950.0000
# 4        9125.0000
#            ...
# 1304     5292.5000
# 1305           NaN
# 1306     9672.5000
# 1307     9855.0000
# 1308    10585.0000
# Name: age, Length: 1309, dtype: float64

# %%
def get_age_group(age):
    if age < 2:
        return "infant"
    elif age < 12:
        return "child"
    elif age < 18:
        return "teen"
    elif age < 50:
        return "adult"
    else: 
        return "senior"

# %%
titanic["age_group"] = titanic["age"].apply(get_age_group)

# %%
titanic.age_group.value_counts()
# Out:
# adult     782
# senior    373
# child      69
# teen       63
# infant     22
# Name: age_group, dtype: int64

# %%
titanic.groupby("age_group").survived.mean()
# Out:
# age_group
# adult     0.386189
# child     0.492754
# infant    0.772727
# senior    0.313673
# teen      0.476190
# Name: survived, dtype: float64

# %%
titanic.groupby(["age_group", "sex"]).survived.mean()
# Out:
# age_group  sex
# adult      female    0.748201
#            male      0.186508
# child      female    0.515152
#            male      0.472222
# infant     female    0.888889
#            male      0.692308
# senior     female    0.698276
#            male      0.140078
# teen       female    0.833333
#            male      0.151515
# Name: survived, dtype: float64

# %%
titanic["fare"] * 24
# Out:
# 0       5072.1000
# 1       3637.2000
# 2       3637.2000
# 3       3637.2000
# 4       3637.2000
#           ...
# 1304     346.9008
# 1305     346.9008
# 1306     173.4000
# 1307     173.4000
# 1308     189.0000
# Name: fare, Length: 1309, dtype: float64

# %%
titanic["fare"].apply(lambda x: f"${x*24}")
# Out:
# 0                   $5072.1
# 1       $3637.2000000000003
# 2       $3637.2000000000003
# 3       $3637.2000000000003
# 4       $3637.2000000000003
#                ...
# 1304              $346.9008
# 1305              $346.9008
# 1306    $173.39999999999998
# 1307    $173.39999999999998
# 1308                 $189.0
# Name: fare, Length: 1309, dtype: object

# %%
def convert_currency(num, multiplier):
    return f"${num *multiplier}"

# %%
titanic["fare"].apply(convert_currency, args=(24,))
# Out:
# 0                   $5072.1
# 1       $3637.2000000000003
# 2       $3637.2000000000003
# 3       $3637.2000000000003
# 4       $3637.2000000000003
#                ...
# 1304              $346.9008
# 1305              $346.9008
# 1306    $173.39999999999998
# 1307    $173.39999999999998
# 1308                 $189.0
# Name: fare, Length: 1309, dtype: object

# %%
df = titanic[["pclass", "survived", "age","fare"]]

# %%
def get_range(s):
    return s.max() - s.min()

# %%
df.apply(get_range, axis=0)
# Out:
# pclass        2.0000
# survived      1.0000
# age          79.8333
# fare        512.3292
# dtype: float64

# %%
def get_fam_size(s):
    fam_size=s.sibsp + s.parch
    if fam_size == 0:
        return "solo"
    elif fam_size < 4:
        return "average"
    else:
        return "large"

# %%
titanic["fam_size"] = titanic.apply(get_fam_size, axis=1)

# %%
titanic.groupby("fam_size").survived.mean()
# Out:
# fam_size
# average    0.562929
# large      0.182927
# solo       0.302532
# Name: survived, dtype: float64

# %%
titanic.groupby(["fam_size", "sex"]).survived.mean()
# Out:
# fam_size  sex
# average   female    0.800866
#           male      0.296117
# large     female    0.292683
#           male      0.073171
# solo      female    0.731959
#           male      0.162752
# Name: survived, dtype: float64

# %%
titanic["pclass"].map({1:"1st", 2:"2nd", 3:"3rd"})
# Out:
# 0       1st
# 1       1st
# 2       1st
# 3       1st
# 4       1st
#        ...
# 1304    3rd
# 1305    3rd
# 1306    3rd
# 1307    3rd
# 1308    3rd
# Name: pclass, Length: 1309, dtype: object

# %%
titanic["age"].map(lambda a: a < 18)
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
titanic[["name", "sex", "age_group"]]
# Out:
#                                                  name     sex age_group
# 0                       Allen, Miss. Elisabeth Walton  female     adult
# 1                      Allison, Master. Hudson Trevor    male    infant
# 2                        Allison, Miss. Helen Loraine  female     child
# 3                Allison, Mr. Hudson Joshua Creighton    male     adult
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female     adult
# ...                                               ...     ...       ...
# 1304                             Zabour, Miss. Hileni  female      teen
# 1305                            Zabour, Miss. Thamine  female    senior
# 1306                        Zakarian, Mr. Mapriededer    male     adult
# 1307                              Zakarian, Mr. Ortin    male     adult
# 1308                               Zimmerman, Mr. Leo    male     adult
#
# [1309 rows x 3 columns]

# %%
titanic[["name", "sex", "age_group"]].applymap(str.upper)
# Out:
#                                                  name     sex age_group
# 0                       ALLEN, MISS. ELISABETH WALTON  FEMALE     ADULT
# 1                      ALLISON, MASTER. HUDSON TREVOR    MALE    INFANT
# 2                        ALLISON, MISS. HELEN LORAINE  FEMALE     CHILD
# 3                ALLISON, MR. HUDSON JOSHUA CREIGHTON    MALE     ADULT
# 4     ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)  FEMALE     ADULT
# ...                                               ...     ...       ...
# 1304                             ZABOUR, MISS. HILENI  FEMALE      TEEN
# 1305                            ZABOUR, MISS. THAMINE  FEMALE    SENIOR
# 1306                        ZAKARIAN, MR. MAPRIEDEDER    MALE     ADULT
# 1307                              ZAKARIAN, MR. ORTIN    MALE     ADULT
# 1308                               ZIMMERMAN, MR. LEO    MALE     ADULT
#
# [1309 rows x 3 columns]

# %%
df.applymap(lambda el: el * 7)
# Out:
#       pclass  survived       age       fare
# 0          7         7  203.0000  1479.3625
# 1          7         7    6.4169  1060.8500
# 2          7         0   14.0000  1060.8500
# 3          7         0  210.0000  1060.8500
# 4          7         0  175.0000  1060.8500
# ...      ...       ...       ...        ...
# 1304      21         0  101.5000   101.1794
# 1305      21         0       NaN   101.1794
# 1306      21         0  185.5000    50.5750
# 1307      21         0  189.0000    50.5750
# 1308      21         0  203.0000    55.1250
#
# [1309 rows x 4 columns]

# %%
titanic[["name", "sex", "age_group"]].applymap(len)
# Out:
#       name  sex  age_group
# 0       29    6          5
# 1       30    4          6
# 2       28    6          5
# 3       36    4          5
# 4       47    6          5
# ...    ...  ...        ...
# 1304    20    6          4
# 1305    21    6          6
# 1306    25    4          5
# 1307    19    4          5
# 1308    18    4          5
#
# [1309 rows x 3 columns]

# %%
s1 = pd.Series(["a", "b", "c"])
s2 = pd.Series(["d","e","f", "z"])

# %%
pd.concat([s1,s2])
# Out:
# 0    a
# 1    b
# 2    c
# 0    d
# 1    e
# 2    f
# 3    z
# dtype: object

# %%
pd.concat([s1,s2], ignore_index=True)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# 6    z
# dtype: object

# %%
nums = pd.Series([65,69,99,23,56,54])

# %%
pd.concat([s1,s2,nums], ignore_index=True)
# Out:
# 0      a
# 1      b
# 2      c
# 3      d
# 4      e
# 5      f
# 6      z
# 7     65
# 8     69
# 9     99
# 10    23
# 11    56
# 12    54
# dtype: object

# %%
nums2 = pd.Series([111,11111,111111])

# %%
pd.concat([nums2,nums], ignore_index=True)
# Out:
# 0       111
# 1     11111
# 2    111111
# 3        65
# 4        69
# 5        99
# 6        23
# 7        56
# 8        54
# dtype: int64

# %%
pd.concat([s1,s2],axis=1)
# Out:
#      0  1
# 0    a  d
# 1    b  e
# 2    c  f
# 3  NaN  z

# %%
fruits = pd.Series(
    data=["apple","banana", "cherry", "durian"],
    index = ["a","b","c","d"]
)
animals = pd.Series(
    data=["badger","cougar", "anaconda", "elk", "pika"],
    index=["b","c","a", "e","p"]
)

# %%
pd.concat([fruits, animals], axis=1)
# Out:
#         0         1
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar
# d  durian       NaN
# e     NaN       elk
# p     NaN      pika

# %%
pd.concat([fruits, animals], axis=1,keys=["fruit", "animals"])
# Out:
#     fruit   animals
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar
# d  durian       NaN
# e     NaN       elk
# p     NaN      pika

# %%
pd.concat([fruits, animals], axis=1,keys=["fruit", "animals"],join="outer")
# Out:
#     fruit   animals
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar
# d  durian       NaN
# e     NaN       elk
# p     NaN      pika

# %%
harvest_21 = pd.DataFrame(
    [['potatoes', 900], ['garlic', 1350], ['onions', 875]], 
    columns=['crop', 'qty']
)

harvest_22 = pd.DataFrame(
    [['garlic', 1600], ['spinach', 560], ['turnips', 999], ['onions', 1000]], 
    columns=['crop', 'qty']
)

# %%
harvest_21
# Out:
#        crop   qty
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875

# %%
harvest_22
# Out:
#       crop   qty
# 0   garlic  1600
# 1  spinach   560
# 2  turnips   999
# 3   onions  1000

# %%
pd.concat([harvest_21,harvest_22],keys=[2021,2022])
# Out:
#             crop   qty
# 2021 0  potatoes   900
#      1    garlic  1350
#      2    onions   875
# 2022 0    garlic  1600
#      1   spinach   560
#      2   turnips   999
#      3    onions  1000

# %%
harvest_23 = pd.DataFrame(
    [['potatoes', 900,500], ['garlic', 1350,1200], ['onions', 875,950]], 
    columns=['crop', 'qty','profit']
)

# %%
harvest_23
# Out:
#        crop   qty  profit
# 0  potatoes   900     500
# 1    garlic  1350    1200
# 2    onions   875     950

# %%
pd.concat([harvest_21,harvest_22,harvest_23])
# Out:
#        crop   qty  profit
# 0  potatoes   900     NaN
# 1    garlic  1350     NaN
# 2    onions   875     NaN
# 0    garlic  1600     NaN
# 1   spinach   560     NaN
# 2   turnips   999     NaN
# 3    onions  1000     NaN
# 0  potatoes   900   500.0
# 1    garlic  1350  1200.0
# 2    onions   875   950.0

# %%
livestock = pd.DataFrame(
    [['pasture', 9], ['stable', 3], ['coop', 34]], 
    columns=['location', 'qty'],
    index=['alpaca', 'horse', 'chicken']
)
weights = pd.DataFrame(
    [[4,10], [900, 2000], [1.2, 4], [110, 150]], 
    columns=['min_weight', 'max_weight'],
    index=['chicken', 'horse', 'duck', 'alpaca']
)

# %%
weights
# Out:
#          min_weight  max_weight
# chicken         4.0          10
# horse         900.0        2000
# duck            1.2           4
# alpaca        110.0         150

# %%
pd.concat([livestock, weights],axis=1)
# Out:
#         location   qty  min_weight  max_weight
# alpaca   pasture   9.0       110.0         150
# horse     stable   3.0       900.0        2000
# chicken     coop  34.0         4.0          10
# duck         NaN   NaN         1.2           4

# %%
pd.concat([livestock, weights],axis=1,join="inner")
# Out:
#         location  qty  min_weight  max_weight
# alpaca   pasture    9       110.0         150
# horse     stable    3       900.0        2000
# chicken     coop   34         4.0          10

# %%
teams = pd.DataFrame(
    [
        ["Suns", "Phoenix", 20, 4], 
        ["Mavericks", "Dallas", 11,12], 
        ["Rockets", "Houston", 7, 16],
        ['Nuggets', "Denver", 11, 12]
    ], 
    columns=["team", "city", "wins", "losses"]
)

# %%
cities = pd.DataFrame(
    [
        ["Houston", "Texas", 2310000], 
        ["Phoenix", "Arizona", 1630000], 
        ["San Diego", "California", 1410000],
        ["Dallas", "Texas", 1310000]
    ],
    columns=["city", "state", "population"]
)

# %%
teams.merge(cities)
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
cities
# Out:
#         city       state  population
# 0    Houston       Texas     2310000
# 1    Phoenix     Arizona     1630000
# 2  San Diego  California     1410000
# 3     Dallas       Texas     1310000

# %%
teams.merge(cities, on="city")
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
teams.merge(cities, on="city", how="left")
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona   1630000.0
# 1  Mavericks   Dallas    11      12    Texas   1310000.0
# 2    Rockets  Houston     7      16    Texas   2310000.0
# 3    Nuggets   Denver    11      12      NaN         NaN

# %%
teams.merge(cities, how="right")
# Out:
#         team       city  wins  losses       state  population
# 0    Rockets    Houston   7.0    16.0       Texas     2310000
# 1       Suns    Phoenix  20.0     4.0     Arizona     1630000
# 2        NaN  San Diego   NaN     NaN  California     1410000
# 3  Mavericks     Dallas  11.0    12.0       Texas     1310000

# %%
teams.merge(cities, how="outer")
# Out:
#         team       city  wins  losses       state  population
# 0       Suns    Phoenix  20.0     4.0     Arizona   1630000.0
# 1  Mavericks     Dallas  11.0    12.0       Texas   1310000.0
# 2    Rockets    Houston   7.0    16.0       Texas   2310000.0
# 3    Nuggets     Denver  11.0    12.0         NaN         NaN
# 4        NaN  San Diego   NaN     NaN  California   1410000.0

# %%
midterms = pd.DataFrame(
    [['alex', 'padilla', 92], ['rayna', 'wilson', 83], ['juan', 'gomez', 78], ['angela', 'smith', 66],['stephen', 'yu', 98]], 
    columns=['first', 'last', 'score']
)
finals = pd.DataFrame(
    [['alex','padilla', 97, False], ['rayna', 'wilson', 88, False], ['alex', 'smith', 86, True], ['juan', 'gomez', 71, True], ['stephen', 'yu', 78, False], ['sakura', 'steel', 100, True]], 
    columns=['first', 'last','score', 'extra_credit']
)

# %%
midterms
# Out:
#      first     last  score
# 0     alex  padilla     92
# 1    rayna   wilson     83
# 2     juan    gomez     78
# 3   angela    smith     66
# 4  stephen       yu     98

# %%
finals
# Out:
#      first     last  score  extra_credit
# 0     alex  padilla     97         False
# 1    rayna   wilson     88         False
# 2     alex    smith     86          True
# 3     juan    gomez     71          True
# 4  stephen       yu     78         False
# 5   sakura    steel    100          True

# %%
midterms.merge(finals, on="first")
# Out:
#      first   last_x  score_x   last_y  score_y  extra_credit
# 0     alex  padilla       92  padilla       97         False
# 1     alex  padilla       92    smith       86          True
# 2    rayna   wilson       83   wilson       88         False
# 3     juan    gomez       78    gomez       71          True
# 4  stephen       yu       98       yu       78         False

# %%
midterms.merge(finals, on=["first", "last"])
# Out:
#      first     last  score_x  score_y  extra_credit
# 0     alex  padilla       92       97         False
# 1    rayna   wilson       83       88         False
# 2     juan    gomez       78       71          True
# 3  stephen       yu       98       78         False

# %%
midterms.merge(finals, on=["first", "last","score"])
# Out:
# Empty DataFrame
# Columns: [first, last, score, extra_credit]
# Index: []

# %%
combo = midterms.merge(finals, on=["first", "last"],suffixes=("_m","_f"))

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit
# 0     alex  padilla       92       97         False
# 1    rayna   wilson       83       88         False
# 2     juan    gomez       78       71          True
# 3  stephen       yu       98       78         False

# %%
combo["avg"] = (combo["score_m"] + combo["score_f"])/2

# %%
combo.loc[combo["extra_credit"] == True, 'avg']
# Out:
# 2    74.5
# Name: avg, dtype: float64
